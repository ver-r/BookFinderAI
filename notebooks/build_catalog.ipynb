# %%
import json
import requests
from datetime import datetime 
import time

API_URL=""
API_TOKEN=""
HEADERS={
    "content-type": "application/json",
    "authorization": API_TOKEN
}

INITIAL_DATASET_PATH=r"E:\book_recommender\data\initial_dataset.json"
CATALOG_PATH=r"E:\book_recommender\data\catalog.json"

# %%
with open(INITIAL_DATASET_PATH,"r") as f:
    initial_data=json.load(f)
all_titles=[]
for genre, titles in initial_data.items():
    all_titles.extend(titles)
unique_titles=list(dict.fromkeys(all_titles))
print("total titles:", len(unique_titles))
# Out:
# total titles: 161

# %%
def load_catalog():
    try:
        with open(CATALOG_PATH, "r") as f:
            return json.load(f)
    except: return {}
def save_catalog(catalog): 
    with open(CATALOG_PATH, "w") as f:
        json.dump(catalog, f, indent=4)
catalog=load_catalog()

# %%
def search_book(title):
    query = """
    query SearchBook($query: String!) {
      search(query: $query, query_type: "Book", per_page: 1) {
        results
        ids
      }
    }
    """

    payload = {
        "query": query,
        "variables": {"query": title}
    }

    try:
        r = requests.post(API_URL, headers=HEADERS, json=payload)
        data = r.json()

        # API error
        if "errors" in data:
            print("API Error:", data["errors"])
            return None

        results = data["data"]["search"]["results"]

        # No hits
        if not results["hits"]:
            return None

        # Return the main metadata object
        return results["hits"][0]["document"]

    except Exception as e:
        print("Request failed:", e)
        return None

# %%
def clean_document(doc):
    return {
        "book_id": doc.get("id"),
        "title": doc.get("title"),
        "authors": doc.get("author_names", []),
        "description": doc.get("description", ""),
        "genres": doc.get("genres", []),
        "tags": doc.get("tags", []),
        "moods": doc.get("moods", []),
        "rating": doc.get("rating"),
        "pages": doc.get("pages"),
        "published_year": doc.get("release_year"),
        "image_url": doc.get("image", {}).get("url"),
        "isbn_list": doc.get("isbns", []),
        "embedding_vector_path": None,
        "added_source": "initial",
        "last_updated": datetime.now().strftime("%Y-%m-%d")
    }

# %%
for title in unique_titles:
    print(f"\nSearching for: {title}")

    # Step 1 — Fetch metadata from API
    doc = search_book(title)

    if doc is None:
        print(" Not found, skipping")
        continue

    # Step 2 — Clean the raw metadata
    cleaned = clean_document(doc)
    book_id = cleaned["book_id"]

    if not book_id:
        print("No book_id returned, skipping")
        continue

    # Step 3 — Check if ID already exists in catalog
    if book_id in catalog:
        print(f" Already exists in catalog (ID: {book_id}) — skipping")
        continue

    # Step 4 — Insert into catalog
    catalog[book_id] = cleaned
    save_catalog(catalog)

    print(f" Added: {cleaned['title']} (ID: {book_id})")

    # Step 5 — Respect rate limits
    time.sleep(0.5)
# Out:
# Searching for: The Da Vinci Code
#  Added: The Da Vinci Code (ID: 373163)
#
# Searching for: Angels & Demons
#  Added: Angels & Demons (ID: 123621)
#
# Searching for: Treasure Island
#  Added: Treasure Island (ID: 382607)
#
# Searching for: The Lost City of Z
#  Added: The Lost City of Z: A Tale of Deadly Obsession in the Amazon (ID: 374999)
#
# Searching for: The Three Musketeers
#  Added: The Three Musketeers (ID: 704789)
#
# Searching for: The Bourne Identity
#  Added: The Bourne Identity (ID: 15201)
#
# Searching for: The Hunt for Red October
#  Added: The Hunt for Red October (ID: 63707)
#
# Searching for: Life of Pi
#  Added: Life of Pi (ID: 259662)
#
# Searching for: Shogun
#  Added: Shōgun (ID: 6705)
#
# Searching for: Ready Player One
#  Added: Ready Player One (ID: 26363)
#
# Searching for: The Martian
#  Added: The Martian (ID: 292354)
#
# Searching for: The Count of Monte Cristo
#  Added: The Count of Monte Cristo (ID: 473869)
#
# Searching for: The Hunger Games
#  Added: The Hunger Games (ID: 88639)
#
# Searching for: Jurassic Park
#  Added: Jurassic Park (ID: 9724)
#
# Searching for: The Maze Runner
#  Added: The Maze Runner (ID: 109009)
#
# Searching for: Gone Girl
#  Added: Gone Girl (ID: 1145808)
#
# Searching for: The Girl with the Dragon Tattoo
#  Added: Girl with the Dragon Tattoo Trilogy Bundle: The Girl with the Dragon Tattoo, The Girl Who Played with Fire, The Girl Who Kicked the Hornet's Nest (ID: 1478942)
#
# Searching for: The Silent Patient
#  Added: The Silent Patient (ID: 187993)
#
# Searching for: The Woman in the Window
#  Added: The Woman in the Window (ID: 430431)
#
# Searching for: Big Little Lies
#  Added: Big Little Lies (ID: 437781)
#
# Searching for: The Reversal
#  Added: The Reversal (ID: 192185)
#
# Searching for: Sharp Objects
#  Added: Sharp Objects (ID: 130839)
#
# Searching for: The Cuckoo's Calling
#  Added: The Cuckoo's Calling (ID: 183498)
#
# Searching for: And Then There Were None
#  Added: And Then There Were None (ID: 374051)
#
# Searching for: The Murder of Roger Ackroyd
#  Added: The Murder of Roger Ackroyd (ID: 380920)
#
# Searching for: The Snowman
#  Added: The Snowman (ID: 260283)
#
# Searching for: Shutter Island
#  Added: Shutter Island (ID: 566861)
#
# Searching for: Killing Floor
#  Added: Killing Floor (ID: 257345)
#
# Searching for: The Girl on the Train
#  Added: The Girl on the Train (ID: 182003)
#
# Searching for: The Name of the Wind
#  Added: The Name of the Wind (ID: 379217)
#
# Searching for: Mistborn
#  Added: Mistborn: The Final Empire (ID: 369692)
#
# Searching for: The Way of Kings
#  Added: The Way of Kings (ID: 386446)
#
# Searching for: A Game of Thrones
#  Added: A Game of Thrones (ID: 644)
#
# Searching for: The Hobbit
#  Added: The Hobbit (ID: 382700)
#
# Searching for: Harry Potter and the Philosopher's Stone
#  Added: Harry Potter and the Sorcerer's Stone (ID: 328491)
#
# Searching for: The Lies of Locke Lamora
#  Added: The Lies of Locke Lamora (ID: 380764)
#
# Searching for: The Priory of the Orange Tree
#  Added: The Priory of the Orange Tree (ID: 428024)
#
# Searching for: Six of Crows
#  Added: Six of Crows (ID: 1898835)
#
# Searching for: The Poppy War
#  Added: The Poppy War (ID: 143200)
#
# Searching for: The Night Circus
#  Added: The Night Circus (ID: 375064)
#
# Searching for: The Cruel Prince
#  Added: The Cruel Prince (ID: 98065)
#
# Searching for: Fourth Wing
#  Added: Fourth Wing (ID: 714600)
#
# Searching for: Shadow and Bone
#  Added: Shadow and Bone (ID: 312762)
#
# Searching for: Good Omens
#  Added: Good Omens: The Nice and Accurate Prophecies of Agnes Nutter, Witch (ID: 434342)
#
# Searching for: The Nightingale
#  Added: The Nightingale (ID: 212769)
#
# Searching for: All the Light We Cannot See
#  Added: All the Light We Cannot See (ID: 478556)
#
# Searching for: The Book Thief
#  Added: The Book Thief (ID: 300042)
#
# Searching for: The Tattooist of Auschwitz
#  Added: The Tattooist of Auschwitz (ID: 433282)
#
# Searching for: The Help
#  Added: The Help (ID: 373226)
#
# Searching for: The Kite Runner
#  Added: The Kite Runner (ID: 71101)
#
# Searching for: A Thousand Splendid Suns
#  Added: A Thousand Splendid Suns (ID: 375663)
#
# Searching for: The Pillars of the Earth
#  Added: Pillars of the Earth: Part 1 of 3 (ID: 2022888)
#
# Searching for: The Guernsey Literary and Potato Peel Pie Society
#  Added: The Guernsey Literary and Potato Peel Pie Society (ID: 287629)
#
# Searching for: Wolf Hall
#  Added: Wolf Hall (ID: 153901)
#
# Searching for: The Alice Network
#  Added: The Alice Network (ID: 257917)
#
# Searching for: The Paris Library
#  Added: The Paris Library (ID: 440117)
#
# Searching for: The Boy in the Striped Pajamas
#  Added: A Literature Kit for The Boy in the Striped Pajamas by John Boyne (ID: 580369)
#
# Searching for: Hamnet
#  Added: Hamnet (ID: 428411)
#
# Searching for: Lessons in Chemistry
#  Added: Lessons in Chemistry (ID: 490300)
#
# Searching for: The Shining
#  Added: The Shining (ID: 280359)
#
# Searching for: IT
#  Added: It (ID: 373525)
#
# Searching for: The Haunting of Hill House
#  Added: The Haunting of Hill House (ID: 71005)
#
# Searching for: Bird Box
#  Added: Bird Box (ID: 432756)
#
# Searching for: The Exorcist
#  Added: The Exorcist (ID: 318352)
#
# Searching for: The Girl Next Door
#  Added: The Girl Next Door (ID: 699248)
#
# Searching for: House of Leaves
#  Added: House of Leaves (ID: 301814)
#
# Searching for: The Cabin at the End of the World
#  Added: The Cabin at the End of the World (ID: 468176)
#
# Searching for: Misery
#  Added: Misery (ID: 547)
#
# Searching for: Pet Sematary
#  Added: Pet Sematary (ID: 385850)
#
# Searching for: The Silent Companions
#  Added: The Silent Companions (ID: 259222)
#
# Searching for: Dracula
#  Added: Dracula (ID: 1209317)
#
# Searching for: Mexican Gothic
#  Added: Mexican Gothic (ID: 428353)
#
# Searching for: The Troop
#  Added: The Troop (ID: 23801)
#
# Searching for: Coraline
#  Added: Coraline (ID: 194560)
#
# Searching for: The Fault in Our Stars
#  Added: The Fault in Our Stars (ID: 197990)
#
# Searching for: The Notebook
#  Added: The Notebook (ID: 383393)
#
# Searching for: Me Before You
#  Added: Me Before You (ID: 379422)
#
# Searching for: The Love Hypothesis
#  Added: The Love Hypothesis (ID: 428778)
#
# Searching for: It Ends With Us
#  Added: It Ends With Us (ID: 379737)
#
# Searching for: Outlander
#  Added: Outlander (ID: 427404)
#
# Searching for: Crazy Rich Asians
#  Added: Crazy Rich Asians (ID: 427499)
#
# Searching for: The Seven Husbands of Evelyn Hugo
#  Added: The Seven Husbands of Evelyn Hugo (ID: 340654)
#
# Searching for: Beach Read
#  Added: Beach Read (ID: 429002)
#
# Searching for: People We Meet on Vacation
#  Added: People We Meet on Vacation (ID: 432661)
#
# Searching for: Book Lovers
#  Added: Book Lovers (ID: 454009)
#
# Searching for: One Last Stop
#  Added: One Last Stop (ID: 429051)
#
# Searching for: The Unhoneymooners
#  Added: The Unhoneymooners (ID: 434771)
#
# Searching for: Red, White & Royal Blue
#  Added: Red, White & Royal Blue (ID: 381772)
#
# Searching for: The Spanish Love Deception
#  Added: The Spanish Love Deception (ID: 431690)
#
# Searching for: Dune
#  Added: Dune (ID: 312460)
#
# Searching for: Ender's Game
#  Added: Ender's Game (ID: 158268)
#
# Searching for: Neuromancer
#  Added: Neuromancer (ID: 313448)
#
# Searching for: Foundation
#  Added: Foundation (ID: 188628)
#
# Searching for: Snow Crash
#  Added: Snow Crash (ID: 92854)
#
# Searching for: Hyperion
#  Added: Hyperion (ID: 427460)
#
# Searching for: Brave New World
#  Added: Brave New World (ID: 374328)
#
# Searching for: The Left Hand of Darkness
#  Added: The Left Hand of Darkness (ID: 377842)
#
# Searching for: The Hitchhiker's Guide to the Galaxy
#  Added: The Ultimate Hitchhiker's Guide to the Galaxy: All Five Novels in One Volume (ID: 2086789)
#
# Searching for: Annihilation
#  Added: Annihilation (ID: 192491)
#
# Searching for: Station Eleven
#  Added: Station Eleven (ID: 427463)
#
# Searching for: The Three-Body Problem
#  Added: The Three-Body Problem (ID: 208339)
#
# Searching for: Dark Matter
#  Added: Dark Matter (ID: 57214)
#
# Searching for: Divergent
#  Added: Divergent (ID: 109344)
#
# Searching for: City of Bones
#  Added: City of Bones (ID: 144062)
#
# Searching for: Looking for Alaska
#  Added: Looking for Alaska (ID: 368817)
#
# Searching for: The Perks of Being a Wallflower
#  Added: The Perks of Being a Wallflower (ID: 1162844)
#
# Searching for: The Giver
#  Added: The Giver (ID: 262039)
#
# Searching for: Aristotle and Dante Discover the Secrets of the Universe
#  Added: Aristotle and Dante Discover the Secrets of the Universe (ID: 336232)
#
# Searching for: Eleanor & Park
#  Added: Eleanor & Park (ID: 228459)
#
# Searching for: One of Us Is Lying
#  Added: One of Us Is Lying (ID: 8999)
#
# Searching for: Red Queen
#  Added: Red Queen (ID: 362965)
#
# Searching for: They Both Die at the End
#  Added: They Both Die at the End (ID: 256277)
#
# Searching for: The Sun Is Also a Star
#  Added: The Sun is Also a Star (ID: 379732)
#
# Searching for: Steve Jobs
#  Added: Steve Jobs (ID: 294341)
#
# Searching for: Einstein
#  Added: Einstein (ID: 324752)
#
# Searching for: Alexander Hamilton
#  Added: Alexander Hamilton (ID: 384468)
#
# Searching for: Becoming
#  Added: Becoming (ID: 337)
#
# Searching for: The Diary of Anne Frank
#  Added: The Diary of a Young Girl   (ID: 469437)
#
# Searching for: Churchill
#  Added: Churchill (ID: 334200)
#
# Searching for: Leonardo da Vinci
#  Added: Leonardo Da Vinci (ID: 1007038)
#
# Searching for: Elon Musk
#  Added: Elon Musk (ID: 887303)
#
# Searching for: Serena Williams
#  Added: On the line (ID: 374073)
#
# Searching for: The Wright Brothers
#  Added: The Wright Brothers (ID: 376011)
#
# Searching for: Educated
#  Added: Educated (ID: 1018039)
#
# Searching for: The Glass Castle
#  Added: The Glass Castle (ID: 12666)
#
# Searching for: When Breath Becomes Air
#  Added: When Breath Becomes Air (ID: 381825)
#
# Searching for: Wild
#  Added: Wild (ID: 430803)
#
# Searching for: Eat, Pray, Love
#  Added: Eat Pray Love: One Woman's Search for Everything Across Italy, India and Indonesia (ID: 111757)
#
# Searching for: I Am Malala
#  Added: I Am Malala (ID: 263320)
#
# Searching for: Born a Crime
#  Added: Born a Crime (ID: 1176707)
#
# Searching for: Night
#  Added: Night (ID: 35078)
#
# Searching for: Just Kids
#  Added: Just Kids (ID: 376077)
#
# Searching for: In Cold Blood
#  Added: In Cold Blood (ID: 1285461)
#
# Searching for: I'll Be Gone in the Dark
#  Added: I'll Be Gone in the Dark: One Woman's Obsessive Search for the Golden State Killer (ID: 173604)
#
# Searching for: Mindhunter
#  Added: Mindhunter (ID: 203700)
#
# Searching for: Helter Skelter
#  Added: HELTER SKELTER (ID: 450757)
#
# Searching for: The Stranger Beside Me
#  Added: The Stranger Beside Me (ID: 335829)
#
# Searching for: The Killer Across the Table
#  Added: Killer Across the Table (ID: 462812)
#
# Searching for: If You Tell
#  Added: If You Tell (ID: 438780)
#
# Searching for: American Predator
#  Added: American Predator (ID: 438826)
#
# Searching for: Columbine
#  Added: Columbine (ID: 360864)
#
# Searching for: The Devil in the White City
#  Added: The Devil in the White City (ID: 211614)
#
# Searching for: Atomic Habits
#  Added: Atomic Habits: An Easy and Proven Way to Build Good Habits and Break Bad Ones (ID: 428023)
#
# Searching for: The Subtle Art of Not Giving a F*ck
#  Added: The Subtle Art of Not Giving a F*ck: A Counterintuitive Approach to Living a Good Life (ID: 242987)
#
# Searching for: The Power of Now
#  Added: The Courage to Be Disliked (ID: 427777)
#
# Searching for: 12 Rules for Life
#  Added: 12 Rules for Life: An Antidote to Chaos (ID: 272075)
#
# Searching for: The Four Agreements
#  Added: The Four Agreements (ID: 606739)
#
# Searching for: Think and Grow Rich
#  Added: Think and Grow Rich (ID: 331156)
#
# Searching for: You Are a Badass
#  Added: You Are a Badass: How to Stop Doubting Your Greatness and Start Living an Awesome Life (ID: 427520)
#
# Searching for: Grit
#  Added: Grit (ID: 1701758)
#
# Searching for: Daring Greatly
#  Added: Daring Greatly: How the Courage to Be Vulnerable Transforms the Way We Live, Love, Parent, and Lead (ID: 427767)
#
# Searching for: The 7 Habits of Highly Effective People
#  Added: The 7 Habits of Highly Effective People (ID: 253778)
#
# Searching for: Sapiens
#  Added: Sapiens (ID: 688722)
#
# Searching for: Guns, Germs, and Steel
#  Added: Guns, Germs & Steel (ID: 505107)
#
# Searching for: The Silk Roads
#  Added: The Silk Roads: A New History of the World (ID: 64605)
#
# Searching for: The Rise and Fall of the Third Reich
#  Added: Rise and Fall of the Third Reich (ID: 498725)
#
# Searching for: A People's History of the United States
#  Added: A People's History of the United States (ID: 95883)
#
# Searching for: The History of the Ancient World
#  Added: A History of the Ancient World (ID: 668740)
#
# Searching for: 1491
#  Added: 1491: New Revelations of the Americas Before Columbus (ID: 16932)
#
# Searching for: The Splendid and the Vile
#  Added: The Splendid and the Vile: A Saga of Churchill, Family, and Defiance During the Blitz (ID: 439788)
#
# Searching for: The Crusades
#  Added: The Crusades (ID: 603972)

# %%
print("Total books in catalog:", len(catalog))
print("Catalog saved at:", CATALOG_PATH)
# Out:
# Total books in catalog: 161
# Catalog saved at: E:\book_recommender\data\catalog.json
